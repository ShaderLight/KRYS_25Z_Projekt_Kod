# %% [markdown]
# ## Uproszczony schemat oleju i octu
#
# Niech $M = (m_{1}, ..., m_{k})$ to będą wiadomości złożone z $k$ elementów wybranych ze skończonego pola $F$ poziomu $q$ (pola Galois poziomu $q$)
#
# Niech $X = (x_{1}, ..., x_{2k})$ składa się z $2k$ elementów, należących do pola $GF(q)$. Wektor $X$ jest prawidłową sygnaturą $M$, jeżeli $G(x) = M$, gdzie $G(X) : GF(q)^{2k} \rightarrow GF(q)^{k}$. Zatem mapowanie $G$ można zapisać jako $G(X) = (G_{1}(X), G_{2}(X), ..., G_{k}(X))$, gdzie $G_{k}(X)$ można zapisać jako $G(X) = \sum_{i}\sum_{j} c_{ij}x_{i}x_{j}$. Widać zatem, że $G_{e}(X) = X^{T} G_{e} X$, gdzie $G_{e}$ to macierz diagonalna $2k$ współczynników.
#
# Każda wiadomość $M$ ma około $qk$ możliwych podpisów, ale znalezienie jakiegokolwiek z nich jest trudne ze względu na nieliniowość równania. Prawdziwy podpisujący może rozwiązać dane równania i obliczyć $X$ wykorzystując strukturę $G$, zdefiniowaną daną konstrukcją:
#
# Niech $A$ będzie losowo wybraną nieosobliwą ($det A \ne 0$) macierzą $2k\times2k$ nad polem $GF(q)$ oraz niech $Y=(y_{1}, ..., y_{2k})$ stanowi $Y=AX$. Niech $F=(F_{1}, ..., F_{k})$ będzie tensorem losowych $k$ macierzy rozmiaru $2k\times2k$ takich, że:
#
# $$
#     F_{e} = \begin{pmatrix}
# 0_{k} & B_{1} \\
# B_{2} & B_{3}
# \end{pmatrix}
# $$
#
# Gdzie $0_{k}$ to macierz zer rozmiaru $k \times k$. Wyprowadzając $F_{e}(Y) = Y^{T} F_{e} Y$. W takim wypadku podstawiając $Y=AX$ otrzymujemy $F_{e}(X) = X^{T} A^{T} F_{e} A X$. Forma ta jest podobna do formy $G(X)$. Kluczem weryfikacyjnym staje się zatem $A^{T} F_{e} A$.
#
# Ukrytym kluczem podpisującego staję się macierz $A$, która wykonuje translacje $X$ do $Y$. Na poziomie zmiennej $Y$ formą kwadratową jest równanie $Y^{T} F_{e} Y$. Fakt, że lewy górny minor $F_{e}$ jest macierzą zerową, oznacza, że dla formy $c_{ij}y_{i}y_{j}$ maksymalnie jedna wartość $i, j$ może być w zakresie $[1, k]$, a więc wszystkie zmienne z pierwszej połowy wektora $Y$ (nazywanych także olejem) pojawiają się liniowo w formie kwadratowej, gdzie wszystkie zmienne z drugiej połowy $Y$ (nazywanych także octem) mogą pojawić się albo liniowo, albo kwadratowo w formach kwadratowych

# %% [markdown]
# $$
#     R = Y^{T} F Y \implies R_{i} = \sum_{j=0}^{2k} y_{i}y_{j}f_{ij} = \sum_{j=k}^{2k} y_{i}y_{j} f_{ij}
# $$
#
# Podpisanie:
# * Przypisz losową wartość octowi $y_{>k} = 0$
# * Uprość równanie kwadratowe, definiowane przez $Y^{T} F_{e} Y = m_{e}$. Wynikowe równanie jest liniowe i zawiera tylko olej
# * Rozwiąż $k$ systemów układów liniowych w $k$ zmiennych. Jeżeli macierze są osobliwę, wylosuj inne liczby i powróć do kroku 1.
# * Dokonaj mapowania $X=A^{-1}Y$
# * $X$ jest podpisem $M$
#
#
# Atakujący musi znać $2k$ zmiennych losowych

# %% [markdown]
# ### Algorytm

# %%
import galois as gf
import numpy as np

from dataclasses import dataclass

FIELD = gf.GF(2 ** 3)

def random_nonsingular_matrix(k: int) -> gf.FieldArray:
    while True:
        matrix = FIELD.Random((k, k))
        if abs(np.linalg.det(matrix)) > 1e-3:
            return matrix


def make_matrix_f(k: int) ->  gf.FieldArray:
    return np.concatenate(
        (np.concatenate((FIELD.Zeros((k, k, k)), FIELD.Random((k, k, k))), axis=2),
        np.concatenate((FIELD.Random((k, k, k)), FIELD.Random((k, k, k))), axis=2)),
        axis=1
    )


@dataclass(frozen=True)
class PublicKey:
    key: gf.FieldArray

    def unsign(self, encrypted: gf.FieldArray) -> gf.FieldArray:
        k = self.key.shape[0]
        assert k * 2 == encrypted.shape[0]
        decrypted = encrypted.reshape((1, 1, 2 * k)) @ self.key @ encrypted.reshape((1, 2 * k, 1))
        assert decrypted.shape[1] == 1
        assert decrypted.shape[2] == 1
        return decrypted[:, 0, 0]

    def validate(self, data: gf.FieldArray, cert: gf.FieldArray) -> bool:
        decrypted = self.unsign(cert)
        return np.equal(decrypted, data)


@dataclass(frozen=True)
class SecretKey:
    A: gf.FieldArray
    F: gf.FieldArray

    @classmethod
    def make_key(cls, k: int) -> "SecretKey":
        return cls(A=random_nonsingular_matrix(2 * k), F=make_matrix_f(k))

    def sign(self, data: gf.FieldArray, repeats: int = 10) -> gf.FieldArray:
        k = data.shape[0]
        assert self.A.shape[0] == k * 2

        for _ in range(repeats):
            vinegar = FIELD.Random((k))

            # Y = [O, V]
            #                [0,  B1] |O|
            # m_e = [O, V] * [B2, B3] |V|

            #                |B1V|
            # m_e = [O, V] * |B2O + B3V|

            # m_e = O^{T} B1V + V^{T}B2O + V^{T}B3V
            # dla skalarów transpozycja nie ma znaczenia, więc O^{T} B1V = (O^{T}B1V)^{T} = V^{T}B1{^T} O
            # m_e = V^{T}B1{^T}O + V^{T}B2O + V^{T}B3V
            # m_e - V^{T}B3V = (V^{T}B1{^T} + V^{T}B2)O
            # M = L * O
            # Co dla wszystkich e daje równanie

            b1 = self.F[:, :k, k:]
            b2 = self.F[:, k:, :k]
            b3 = self.F[:, k:, k:]

            matrix = vinegar.reshape((1, 1, k)) @ (b1.swapaxes(1, 2) + b2)
            assert matrix.shape[1] == 1

            matrix = matrix[:, 0, :] # usuń nieistotne wymiary jednościowe
            left_mat = vinegar.reshape((1, 1, k)) @ b3 @ vinegar.reshape((1, k, 1))
            assert left_mat.shape[1] == 1
            assert left_mat.shape[2] == 1
            left = data - left_mat[:, 0, 0] # usuń nieistotne wymiary jednościowe

            # left = matrix * O
            # O = matrix^{-1} * left
            try:
                oil = np.linalg.solve(matrix, left)
            except np.linalg.LinAlgError:
                continue # Macierz jest osobliwa, spróbujmy ponownie

            y = np.concatenate((oil, vinegar), axis=0).reshape(2 * k, 1)

            return (np.linalg.inv(self.A) @ y)[:, 0]


        raise ValueError(f'Tried to sign data {repeats} times but without success')

    @property
    def public_key(self) -> PublicKey:
        return PublicKey(key=self.A.T @ self.F @ self.A)


key = SecretKey.make_key(2)

original = FIELD.Random((2))
cert = key.sign(original)

public = key.public_key

print("Original: ", original)
print("Cert: ", cert)

decrypted = public.unsign(cert)
print("Decrypted: ", decrypted)
# Out:
# Original:  [7 5]
# Cert:  [2 7 6 7]
# Decrypted:  [7 5]

# %% [markdown]
# ## Atak linearyzujący
#
# Na początku musimy założyć, że każda macierz $G_{e} = A^{T}F_{e}A$ jest nieosobliwa. Jeżeli jest osobliwa, to nie jest ona brana dalej pod uwagę. Następnie konieczne jest zdefiniowanie zbioru $T$, który stanowi domknięcie zbioru wszystkich macierzy $G_{ij}=G^{-1}_{i}G_{j}$ nad operacją dodawania, mnożenia oraz mnożenia przez stałą z $GF(k)$.

# %%
# Scipy posiada wygodną funkcję do usuwania liniowo zależnych wierszy z macierzy,
# ale niestety nie wspiera ona operacji na polach Galois. Z tego powodu problematyczne
# funkcje zostały zmockowane ich poprawdzie dzałającymi wariantami, co pozwala
# na prawidłowe użycie funkcji
from scipy.optimize import _remove_redundancy
from scipy.linalg import lu_solve

_remove_redundancy.np.allclose = lambda a, b: np.all(a, FIELD(b))

def plu_decompose(x: gf.FieldArray) -> tuple[tuple[gf.FieldArray, gf.FieldArray], gf.FieldArray]:
    p, l, u = x.plu_decompose()
    return (l, u), p

_remove_redundancy.scipy.linalg.lu_factor = plu_decompose
# _remove_redundancy.scipy.linalg.lu_solve

# %%
from itertools import product
from typing import Generator

class Closure:
    def __init__(self, key: PublicKey) -> None:
        self.__non_singular = list(filter(lambda x: abs(np.linalg.det(x)) > 1e-8, key.key))

    # @classmethod
    # def __remove_lineary_dependent(cls, data: list[gf.FieldArray]) -> list[gf.FieldArray]:
    #     flattened = np.stack(list(map(gf.FieldArray.flatten, data)), axis=0)
    #     result, *_ = _remove_redundancy._remove_redundancy_pivot_dense(flattened, FIELD.Zeros(len(flattened)))
    #     return [matrix.reshape(data[0].shape) for matrix in result]

    def __iter__(self) -> Generator[gf.FieldArray]:
        yield from [np.linalg.inv(gi) @ gj for gi, gj in product(self.__non_singular, self.__non_singular)]
        # yield from (generator := self.__remove_lineary_dependent(generator))
        # Jeżeli tyle nie wystarczy, to zacznijmy przetwarzać iloczyny

        # while True:
        #     old_gen_len = len(generator)
        #     new_hope = [a * b for a, b in product(generator, generator)]
        #     generator = self.__remove_lineary_dependent(generator + new_hope)
        #     if len(generator) == old_gen_len:
        #         return
        #     yield from generator[old_gen_len:]

# %%
print(len(list(Closure(public))))
# Out:
# 4

# %% [markdown]
# ## Bazowe
#
# $T_{1}R_{1}$
#
# $$
#     ( T_{1} R, T_{2}R, T_{3}R, ..., T_{n}R)
# $$
#
# $$
#     \begin{pmatrix}
#     \sum_{i}T^{1}_{0, i}r_{i} & \sum_{i}T^{2}_{0, i}r_{i} & ... & \sum_{i}T^{n}_{0, i}r_{i}\\
#     \sum_{i}T^{1}_{1, i}r_{i} & \sum_{i}T^{2}_{1, i}r_{i} & ... & \sum_{i}T^{n}_{1, i}r_{i} \\
#     ... & ... & ... & ... \\
#     \sum_{i}T^{1}_{2k, i}r_{i} & \sum_{i}T^{2}_{2k, i}r_{i} & ... & \sum_{i}T^{n}_{2k, i}r_{i} \\
#     \end{pmatrix}
# $$
#
# $$ \left( M_{k+1} = \sum_{k} s_{k} M_{i} \right)$$
#
# $$
#     M_{k} = \begin{pmatrix}
#     \sum_{i}T^{1}_{k, i}r_{i} & \sum_{i}T^{2}_{k, i}r_{i} & ... & \sum_{i}T^{N}_{k, i}r_{i} \\
#     \end{pmatrix}
# $$
#
# $$
#     M_{k+1} = \begin{pmatrix}
#     \sum_{j}\sum_{k}T^{1}_{k, i}r_{i}s_{k} & \sum_{j}\sum_{k}T^{2}_{k, i}r_{i}s_{k} & ... & \sum_{j}\sum_{k}T^{N}_{k, i}r_{i}s_{k} \\
#     \end{pmatrix}
# $$
#
# $$
#    \begin{pmatrix}
#     \sum_{i}T^{1}_{k+1, i}r_{i} & \sum_{i}T^{2}_{k+1, i}r_{i} & ... & \sum_{i}T^{N}_{k+1, i}r_{i} \\
#     \end{pmatrix} = \begin{pmatrix}
#     \sum_{j}\sum_{i}T^{1}_{k, i}r_{i}s_{j} & \sum_{j}\sum_{i}T^{2}_{k, i}r_{i}s_{j} & ... & \sum_{j}\sum_{i}T^{N}_{k, i}r_{i}s_{j} \\
#     \end{pmatrix}
# $$

# %% [markdown]
# $$
#     \sum_{i}T^{1}_{k+1, i}r_{i} = \sum_{i}\sum_{j} T^{1}_{j} r_{i}s_{j}
# $$
# $$
#     \sum_{i}T^{p}_{k+1, i}r_{i} = \sum_{i}\sum_{j} T^{p}_{j} r_{i}s_{j}
# $$
#
# Lineralyzacja
#
# $$
# \sum_{i}T^{p}_{k+1, i}r_{i} = \sum_{i}\sum_{j} T^{p}_{j} z_{ij}
# $$

# %% [markdown]
# ## Naiwna
#
# $$
#     c_{p} = \sum_{i}r_{i} \sum_{k} T^{p}_{k, i}  s_{k}
#
# $$
#
# $$
#     c_{p} = S^{T} T^{p} R
# $$
#
# $$
#     c_{p} = R^{T}T^{T}_{p} S
# $$
#
# $$
#     C = O S
# $$
#
# $$
#     O^{-1}C = S
# $$

# %%
def naive_linear(public: PublicKey, count: int = 5000) -> tuple[gf.FieldArray, gf.FieldArray]:
    for _ in range(count):
        k2 = public.key.shape[-1]
        k = k2 // 2
        r = FIELD.Random((k2))
        closure = np.stack(list(Closure(public)), axis=0)
        n = closure.shape[0]

        C = closure[:, k + 1, :].reshape((n, k2)) @ r.reshape((k2, 1))
        C = C.reshape((n))

        lhs = r.reshape((1, 1, k2)) @ closure[:, :k, :].swapaxes(1, 2)
        lhs = lhs.reshape((n, k))
        sublhs = lhs[:k, :]
        suplhs = lhs[k:, :]

        try:
            S = np.linalg.inv(sublhs) @ C[:k]
        except np.linalg.LinAlgError:
            continue

        if np.all(suplhs @ S == C[k:]):
            return r, S

        if _ % 20 == 19:
            print(_)
    raise ValueError("Cannot find a solution")


r, s = naive_linear(public)

print(r, s)
# Out:
# [7 4 0 0] [4 7]

# %%
def make_oil_base(public: PublicKey, count: int = 50) -> gf.FieldArray:
    k = public.key.shape[-1] // 2
    for _ in range(count):
        base = []
        for i in range(k):
            base.append(FIELD(np.array([0] * (k + i) + [1] + [0] * (k - i - 1))))
        for _ in range(k):
            base.append(naive_linear(public)[0])
        base = np.stack(base, axis=0)
        if np.linalg.det(base) != 0:
            return base

# %%
oil_base = make_oil_base(public)
print(oil_base)
# Out:
# [[0 0 1 0]
#  [0 0 0 1]
#  [6 5 7 7]
#  [4 1 7 2]]

# %%
def forge_key(oil_base: gf.FieldArray, public: PublicKey) -> gf.FieldArray:
    return oil_base.T @ public.key @ oil_base

forged = forge_key(oil_base, public)
print("Forged: ", forged)

forged_private = SecretKey(A=oil_base, F=forged)

data = FIELD(np.array([0, 4]))
forged_cert = forged_private.sign(data)

print(f"Data: {data}")
print(f"Forged: {forged_cert}")

print(f"Verify: {public.unsign(forged_cert)}")
# Out:
# Forged:  [[[5 5 7 0]
#   [2 4 3 4]
#   [4 0 5 2]
#   [3 1 3 0]]
#
#  [[5 4 3 1]
#   [3 1 7 6]
#   [2 4 3 6]
#   [2 1 7 6]]]
# Data: [0 4]
# Forged: [5 2 2 3]
# Verify: [0 4]

# %%
def kernel(matrix: gf.FieldArray) -> gf.FieldArray:
    return np.linalg.solve(matrix, FIELD.Zeros((matrix.shape[-1], 1)))

def characteristic_poly_2(public: PublicKey, count: int = 10000) -> gf.FieldArray:
    for _ in range(count):
        g_i = FIELD.Zeros(public.key.shape[1:])
        g_j = FIELD.Zeros(public.key.shape[1:])

        while abs(np.linalg.det(g_i)) < 1e-8:
            g_i = FIELD.Zeros(g_i.shape)
            for g in public.key:
                g_i += FIELD.Random((1)) * g

        while abs(np.linalg.det(g_j)) < 1e-8:
            g_j = FIELD.Zeros(g_j.shape)
            for g in public.key:
                g_j += FIELD.Random((1)) * g

        g_ij = np.linalg.inv(g_i) * g_j

        polys, coeffs = g_ij.characteristic_poly().factors()
        if len(coeffs) == 2:
            first_kernel = polys[0](g_ij).null_space()
            second_kernel = polys[1](g_ij).null_space()
            if first_kernel.shape[0] == public.key.shape[-1] // 2:
                return first_kernel
            if second_kernel.shape[0] == public.key.shape[-1] // 2:
                return second_kernel
        print(_, len(coeffs), polys, coeffs)
    raise ValueError("Cannot find a solution")

# %%
characteristic_poly_2(public)
# Out:
# 0 1 [Poly(x^8 + x^7 + 2x^6 + x^5 + 3x^4 + 7x^2 + x + 3, GF(2^3))] [1]
# 1 3 [Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^3 + 4x^2 + 4x + 3, GF(2^3)), Poly(x^3 + 7x^2 + 4x + 4, GF(2^3))] [1, 1, 1]
# 2 2 [Poly(x^4 + 2x^3 + 5x^2 + 6x + 6, GF(2^3)), Poly(x^4 + 5x^3 + 5x^2 + 3x + 5, GF(2^3))] [1, 1]
# 3 1 [Poly(x^8 + 5x^7 + 4x^6 + 6x^5 + x^4 + 5x^3 + 2x^2 + 3x + 2, GF(2^3))] [1]
# 4 4 [Poly(x, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^5 + 6x^4 + 4x^3 + 6x^2 + 4x + 5, GF(2^3))] [1, 1, 1, 1]
# 5 1 [Poly(x^8 + x^7 + 7x^5 + 3x^4 + 4x^3 + 7x^2 + x + 2, GF(2^3))] [1]
# 6 2 [Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^6 + x^5 + 5x^4 + 3x^3 + 7x^2 + x + 3, GF(2^3))] [1, 1]
# 7 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^5 + 4x^4 + 6x^3 + 5, GF(2^3))] [1, 1, 1]
# 8 2 [Poly(x + 7, GF(2^3)), Poly(x^6 + 5x^5 + 5x^4 + 2x^3 + 4x^2 + x + 1, GF(2^3))] [2, 1]
# 9 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 5x + 3, GF(2^3))] [3, 1, 1]
# 10 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^5 + x^4 + x^3 + 6x^2 + 7x + 6, GF(2^3))] [1, 1, 1]
# 11 2 [Poly(x^4 + 3x^3 + 2x^2 + 5x + 7, GF(2^3)), Poly(x^4 + 3x^3 + 4x^2 + 2x + 7, GF(2^3))] [1, 1]
# 12 1 [Poly(x^8 + 7x^7 + 2x^6 + 2x^5 + x^4 + 3x^3 + 7x^2 + 7x + 5, GF(2^3))] [1]
# 13 2 [Poly(x^3 + x^2 + 4x + 1, GF(2^3)), Poly(x^5 + 3x^4 + 5x^3 + 4x^2 + 3x + 4, GF(2^3))] [1, 1]
# 14 1 [Poly(x^8 + 7x^7 + 5x^6 + 4x^5 + x^4 + 3x^2 + 2x + 3, GF(2^3))] [1]
# 15 4 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^5 + 3x^4 + 4x^2 + 2x + 2, GF(2^3))] [1, 1, 1, 1]
# 16 4 [Poly(x + 6, GF(2^3)), Poly(x^2 + x + 7, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^3 + 2x^2 + 6x + 3, GF(2^3))] [1, 1, 1, 1]
# 17 2 [Poly(x + 3, GF(2^3)), Poly(x^6 + 3x^5 + 7x^4 + x^2 + 6x + 1, GF(2^3))] [2, 1]
# 18 4 [Poly(x + 1, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + 5x + 6, GF(2^3)), Poly(x^3 + 3x^2 + 7x + 7, GF(2^3))] [1, 2, 1, 1]
# 19 4 [Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^5 + 2x^4 + 5x^2 + 5x + 7, GF(2^3))] [1, 1, 1, 1]
# 20 4 [Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^4 + 6x^2 + 6x + 3, GF(2^3))] [1, 1, 1, 1]
# 21 3 [Poly(x + 1, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + x^5 + 2x^4 + 5x^3 + 4x^2 + 2x + 6, GF(2^3))] [1, 1, 1]
# 22 4 [Poly(x + 3, GF(2^3)), Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^3 + x^2 + 7x + 5, GF(2^3))] [1, 1, 1, 1]
# 23 3 [Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^2 + 5x + 2, GF(2^3)), Poly(x^4 + x^3 + 3x^2 + 7x + 3, GF(2^3))] [1, 1, 1]
# 24 3 [Poly(x, GF(2^3)), Poly(x^3 + 3x + 3, GF(2^3)), Poly(x^4 + 2x^3 + 4x^2 + 2x + 1, GF(2^3))] [1, 1, 1]
# 25 3 [Poly(x + 4, GF(2^3)), Poly(x^3 + 5x^2 + 2x + 2, GF(2^3)), Poly(x^4 + 7x^3 + 7x^2 + 5x + 7, GF(2^3))] [1, 1, 1]
# 26 3 [Poly(x + 4, GF(2^3)), Poly(x^2 + 2x + 7, GF(2^3)), Poly(x^5 + 4x^4 + 6x^3 + 2x^2 + 6x + 4, GF(2^3))] [1, 1, 1]
# 27 3 [Poly(x, GF(2^3)), Poly(x^3 + 7x^2 + 6x + 1, GF(2^3)), Poly(x^4 + 4x^3 + 6x^2 + 6x + 4, GF(2^3))] [1, 1, 1]
# 28 4 [Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 3x + 7, GF(2^3)), Poly(x^4 + x^3 + 3x^2 + x + 7, GF(2^3))] [1, 1, 1, 1]
# 29 3 [Poly(x + 3, GF(2^3)), Poly(x^3 + x^2 + 2x + 5, GF(2^3)), Poly(x^4 + 7x^3 + 5, GF(2^3))] [1, 1, 1]
# 30 4 [Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^3 + 4x^2 + 7x + 7, GF(2^3)), Poly(x^3 + 6x^2 + 3x + 3, GF(2^3))] [1, 1, 1, 1]
# 31 4 [Poly(x, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 6x^3 + 5x^2 + 4, GF(2^3))] [1, 1, 1, 1]
# 32 4 [Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 4x + 4, GF(2^3)), Poly(x^3 + 3x^2 + 4x + 5, GF(2^3))] [2, 1, 1, 1]
# 33 3 [Poly(x + 2, GF(2^3)), Poly(x^2 + 2x + 4, GF(2^3)), Poly(x^5 + 3x^4 + 5x^3 + 4x^2 + 2x + 7, GF(2^3))] [1, 1, 1]
# 34 3 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^5 + 7x^4 + 4x^3 + 2x^2 + 7x + 3, GF(2^3))] [1, 2, 1]
# 35 4 [Poly(x + 3, GF(2^3)), Poly(x^2 + 3x + 7, GF(2^3)), Poly(x^2 + 7x + 4, GF(2^3)), Poly(x^3 + 7x^2 + 4, GF(2^3))] [1, 1, 1, 1]
# 36 2 [Poly(x + 6, GF(2^3)), Poly(x^7 + 6x^5 + 3x^4 + x^3 + 5x^2 + 6, GF(2^3))] [1, 1]
# 37 3 [Poly(x, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + 5x^5 + 4x^4 + 5x^3 + 6x^2 + 2, GF(2^3))] [1, 1, 1]
# 38 4 [Poly(x + 6, GF(2^3)), Poly(x^2 + 3x + 4, GF(2^3)), Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^3 + 4x^2 + 2x + 2, GF(2^3))] [1, 1, 1, 1]
# 39 1 [Poly(x^8 + 7x^7 + x^6 + 7x^5 + 3x^4 + 7x^3 + 6x^2 + x + 2, GF(2^3))] [1]
# 40 3 [Poly(x + 2, GF(2^3)), Poly(x^2 + 4x + 6, GF(2^3)), Poly(x^4 + 6x^3 + x^2 + x + 2, GF(2^3))] [2, 1, 1]
# 41 3 [Poly(x + 4, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + x^5 + x^4 + 3x^3 + 4x^2 + 3x + 7, GF(2^3))] [1, 1, 1]
# 42 2 [Poly(x + 7, GF(2^3)), Poly(x^7 + 7x^6 + 2x^5 + x^4 + 5x^3 + 6x^2 + 7x + 7, GF(2^3))] [1, 1]
# 43 1 [Poly(x^8 + 5x^7 + x^6 + 4x^5 + 5x^3 + 2x + 4, GF(2^3))] [1]
# 44 4 [Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^4 + 4x^3 + 4x^2 + 3x + 5, GF(2^3))] [1, 1, 1, 1]
# 45 3 [Poly(x^2 + x + 5, GF(2^3)), Poly(x^2 + x + 7, GF(2^3)), Poly(x^4 + 6x^3 + 3x^2 + 3x + 2, GF(2^3))] [1, 1, 1]
# 46 3 [Poly(x + 5, GF(2^3)), Poly(x^3 + 6x^2 + 1, GF(2^3)), Poly(x^4 + 7x^3 + 2x + 3, GF(2^3))] [1, 1, 1]
# 47 1 [Poly(x^8 + 4x^7 + 4x^6 + 3x^5 + 3x^4 + 3x^3 + x^2 + x + 1, GF(2^3))] [1]
# 48 2 [Poly(x^4 + 5x^3 + 7x + 2, GF(2^3)), Poly(x^4 + 7x^3 + x^2 + 2x + 3, GF(2^3))] [1, 1]
# 49 4 [Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 7x + 4, GF(2^3)), Poly(x^4 + x^3 + 2x^2 + 5x + 3, GF(2^3))] [1, 1, 1, 1]
# 50 3 [Poly(x + 4, GF(2^3)), Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^5 + 7x^4 + x^2 + 6x + 6, GF(2^3))] [1, 1, 1]
# 51 3 [Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^3 + 5x^2 + 2x + 7, GF(2^3)), Poly(x^3 + 5x^2 + 6x + 1, GF(2^3))] [1, 1, 1]
# 52 1 [Poly(x^8 + 7x^7 + 2x^6 + 5x^5 + 4x^4 + 2x^3 + x^2 + 5x + 6, GF(2^3))] [1]
# 53 3 [Poly(x + 2, GF(2^3)), Poly(x^2 + x + 7, GF(2^3)), Poly(x^3 + x^2 + 6x + 4, GF(2^3))] [1, 2, 1]
# 54 3 [Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 6x^5 + x^4 + 6x^3 + 4x^2 + 4x + 1, GF(2^3))] [1, 1, 1]
# 55 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + 3x^6 + 4x^5 + x^4 + 5x^3 + 6x^2 + 5x + 3, GF(2^3))] [1, 1]
# 56 2 [Poly(x^3 + 3x^2 + x + 4, GF(2^3)), Poly(x^5 + 4x^4 + 4x^3 + 3x^2 + 3x + 6, GF(2^3))] [1, 1]
# 57 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + 4x + 6, GF(2^3)), Poly(x^5 + 5x^4 + 2x^3 + 7x^2 + x + 7, GF(2^3))] [1, 1, 1]
# 58 2 [Poly(x + 4, GF(2^3)), Poly(x^7 + x^6 + 6x^5 + 5x^4 + 7x^2 + x + 1, GF(2^3))] [1, 1]
# 59 4 [Poly(x + 2, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^3 + 4x + 1, GF(2^3)), Poly(x^3 + 4x^2 + 2x + 2, GF(2^3))] [1, 1, 1, 1]
# 60 1 [Poly(x^8 + 3x^7 + 7x^6 + 5x^5 + 4x^4 + 4x^3 + 4x^2 + 5x + 2, GF(2^3))] [1]
# 61 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 5x^6 + 7x^5 + 5x^4 + 3x + 7, GF(2^3))] [1, 1]
# 62 4 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^5 + 4x^4 + 6x^3 + 7x^2 + 6x + 6, GF(2^3))] [1, 1, 1, 1]
# 63 2 [Poly(x, GF(2^3)), Poly(x^7 + 6x^6 + x^5 + 2x^4 + 5x^3 + 7x^2 + 7x + 7, GF(2^3))] [1, 1]
# 64 4 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^3 + x^2 + 2x + 1, GF(2^3)), Poly(x^3 + 6x^2 + 1, GF(2^3))] [1, 1, 1, 1]
# 65 4 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^2 + 7x + 4, GF(2^3)), Poly(x^4 + 2x^2 + 3x + 6, GF(2^3))] [1, 1, 1, 1]
# 66 2 [Poly(x + 7, GF(2^3)), Poly(x^7 + 2x^6 + 2x^5 + x^4 + 6x^3 + 4x^2 + x + 5, GF(2^3))] [1, 1]
# 67 4 [Poly(x + 1, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^5 + 5x^4 + 6x^3 + 7x^2 + 5x + 4, GF(2^3))] [1, 1, 1, 1]
# 68 4 [Poly(x + 1, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 3x + 1, GF(2^3)), Poly(x^3 + 4x^2 + x + 6, GF(2^3))] [1, 1, 1, 1]
# 69 2 [Poly(x + 2, GF(2^3)), Poly(x^7 + x^6 + 7x^5 + 3x^4 + 6x^3 + 6x^2 + 5x + 4, GF(2^3))] [1, 1]
# 70 4 [Poly(x + 4, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^4 + 2x^3 + x^2 + 4x + 2, GF(2^3))] [1, 1, 1, 1]
# 71 3 [Poly(x, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 7x^5 + 7x^4 + 3x^3 + 3x^2 + 4x + 2, GF(2^3))] [1, 1, 1]
# 72 3 [Poly(x, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x^6 + 5x^3 + 7x + 2, GF(2^3))] [1, 1, 1]
# 73 3 [Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^4 + 4x^3 + 7x^2 + 2x + 5, GF(2^3))] [1, 3, 1]
# 74 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 4x^3 + x^2 + 6x + 4, GF(2^3))] [2, 1, 1]
# 75 2 [Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^6 + 3x^5 + x^3 + 2x^2 + 2x + 5, GF(2^3))] [1, 1]
# 76 5 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + 5x + 6, GF(2^3)), Poly(x^3 + 4x^2 + 3, GF(2^3))] [1, 1, 1, 1, 1]
# 77 2 [Poly(x^4 + 7x^3 + 2x^2 + x + 3, GF(2^3)), Poly(x^4 + 7x^3 + 5x^2 + 2x + 3, GF(2^3))] [1, 1]
# 78 1 [Poly(x^8 + 2x^7 + 2x^6 + x^4 + 3x^3 + 2x^2 + 6x + 1, GF(2^3))] [1]
# 79 4 [Poly(x, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3))] [2, 1, 3, 1]
# 80 4 [Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^4 + 7x^3 + 2x^2 + 2x + 2, GF(2^3))] [1, 1, 1, 1]
# 81 2 [Poly(x^4 + x^2 + 3x + 2, GF(2^3)), Poly(x^4 + x^3 + 2x^2 + 2x + 6, GF(2^3))] [1, 1]
# 82 4 [Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + x + 3, GF(2^3)), Poly(x^4 + 6x^3 + 4x^2 + 7x + 3, GF(2^3))] [1, 1, 1, 1]
# 83 3 [Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^4 + 3x^3 + 5x^2 + 6, GF(2^3))] [3, 1, 1]
# 84 3 [Poly(x, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 6x^4 + 2x^3 + 6x^2 + 2x + 5, GF(2^3))] [1, 1, 1]
# 85 2 [Poly(x^3 + 5x^2 + 5x + 6, GF(2^3)), Poly(x^5 + 5x^4 + 3x^3 + 2x^2 + 7, GF(2^3))] [1, 1]
# 86 4 [Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^3 + x + 2, GF(2^3)), Poly(x^3 + 5x^2 + 2x + 7, GF(2^3))] [1, 1, 1, 1]
# 87 2 [Poly(x, GF(2^3)), Poly(x^7 + 7x^6 + 3x^4 + 2x^3 + 7x^2 + 3x + 2, GF(2^3))] [1, 1]
# 88 1 [Poly(x^8 + 2x^7 + 3x^6 + 4x^5 + 2x^3 + 4x^2 + 6, GF(2^3))] [1]
# 89 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 5x^6 + 4x^4 + 6x^3 + 4x + 6, GF(2^3))] [1, 1]
# 90 3 [Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + x^5 + 6x^4 + x^3 + 5x^2 + 7x + 7, GF(2^3))] [1, 1, 1]
# 91 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + 3x^6 + 2x^5 + 2x^4 + 5x^3 + 7x^2 + 4x + 3, GF(2^3))] [1, 1]
# 92 4 [Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^4 + 4x^2 + 4x + 4, GF(2^3))] [2, 1, 1, 1]
# 93 1 [Poly(x^8 + 3x^5 + x^4 + 3x^3 + 5x^2 + 4x + 6, GF(2^3))] [1]
# 94 4 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^4 + 4x^3 + 7x^2 + 1, GF(2^3))] [1, 2, 1, 1]
# 95 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^5 + 2x^4 + 7x^3 + x^2 + 3x + 2, GF(2^3))] [1, 1, 1]
# 96 1 [Poly(x^8 + 4x^7 + 4x^6 + 7x^5 + 6x^4 + 6x^2 + 2x + 2, GF(2^3))] [1]
# 97 3 [Poly(x + 2, GF(2^3)), Poly(x^2 + x + 1, GF(2^3)), Poly(x^5 + 7x^2 + 5x + 6, GF(2^3))] [1, 1, 1]
# 98 4 [Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^5 + 2x^4 + 7x^3 + x^2 + 6x + 7, GF(2^3))] [1, 1, 1, 1]
# 99 3 [Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + 7x^4 + 6x^3 + 5x^2 + 3, GF(2^3))] [1, 1, 1]
# 100 3 [Poly(x + 7, GF(2^3)), Poly(x^3 + 6x + 2, GF(2^3)), Poly(x^4 + x^3 + 4x^2 + 6x + 5, GF(2^3))] [1, 1, 1]
# 101 3 [Poly(x, GF(2^3)), Poly(x^3 + 6x^2 + 3x + 5, GF(2^3)), Poly(x^4 + 2x^3 + 6x^2 + 2x + 6, GF(2^3))] [1, 1, 1]
# 102 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 5x^6 + 3x^4 + x^3 + x^2 + 3x + 7, GF(2^3))] [1, 1]
# 103 2 [Poly(x + 5, GF(2^3)), Poly(x^5 + 4x^3 + x^2 + x + 4, GF(2^3))] [3, 1]
# 104 3 [Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 7x^5 + x^4 + 2x^3 + 5x^2 + 6, GF(2^3))] [1, 1, 1]
# 105 2 [Poly(x + 2, GF(2^3)), Poly(x^6 + x^5 + x^4 + 3x^3 + 6x^2 + 5, GF(2^3))] [2, 1]
# 106 1 [Poly(x^8 + 2x^7 + x^6 + 4x^3 + 2x^2 + 2x + 2, GF(2^3))] [1]
# 107 4 [Poly(x, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^4 + 7x + 4, GF(2^3))] [1, 1, 1, 1]
# 108 2 [Poly(x^3 + x^2 + 2, GF(2^3)), Poly(x^5 + 6x^4 + 5x^3 + 2x^2 + 3x + 5, GF(2^3))] [1, 1]
# 109 2 [Poly(x + 3, GF(2^3)), Poly(x^7 + 5x^5 + 2x^4 + 4x^2 + 7x + 6, GF(2^3))] [1, 1]
# 110 4 [Poly(x, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^4 + 6x^2 + 4x + 4, GF(2^3))] [1, 1, 1, 1]
# 111 2 [Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^6 + 2x^5 + 6x^4 + 3x^3 + 5x + 7, GF(2^3))] [1, 1]
# 112 2 [Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^6 + x^4 + 5x^3 + x^2 + 4x + 5, GF(2^3))] [1, 1]
# 113 3 [Poly(x + 1, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + x^5 + x^4 + 4x^3 + 5x^2 + 5x + 2, GF(2^3))] [1, 1, 1]
# 114 4 [Poly(x + 5, GF(2^3)), Poly(x^2 + 5x + 6, GF(2^3)), Poly(x^2 + 7x + 2, GF(2^3)), Poly(x^3 + 2x^2 + 5x + 7, GF(2^3))] [1, 1, 1, 1]
# 115 2 [Poly(x^3 + 6x^2 + 6x + 4, GF(2^3)), Poly(x^5 + x^4 + 4x^3 + 5x^2 + x + 5, GF(2^3))] [1, 1]
# 116 4 [Poly(x, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^4 + 3x^3 + 5x^2 + 4x + 7, GF(2^3))] [1, 1, 1, 1]
# 117 4 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^4 + 5x^3 + 2x^2 + 3x + 6, GF(2^3))] [1, 1, 1, 1]
# 118 4 [Poly(x, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^3 + 2x^2 + 2x + 7, GF(2^3))] [2, 1, 1, 1]
# 119 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + 3x + 7, GF(2^3)), Poly(x^5 + 4x^4 + 2x^3 + 4x^2 + 5x + 7, GF(2^3))] [1, 1, 1]
# 120 3 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 3x^5 + 6x^3 + 6x^2 + 7x + 1, GF(2^3))] [1, 1, 1]
# 121 4 [Poly(x + 1, GF(2^3)), Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^3 + 5x + 3, GF(2^3))] [1, 1, 1, 1]
# 122 2 [Poly(x, GF(2^3)), Poly(x^7 + 3x^6 + 4x^4 + 2x^3 + 2x^2 + 4x + 3, GF(2^3))] [1, 1]
# 123 2 [Poly(x, GF(2^3)), Poly(x^7 + 6x^6 + 4x^5 + 4x^4 + x^3 + 4x^2 + 3x + 7, GF(2^3))] [1, 1]
# 124 2 [Poly(x + 3, GF(2^3)), Poly(x^7 + 7x^6 + 4x^5 + 6x^4 + 4x^3 + 6x^2 + 6x + 4, GF(2^3))] [1, 1]
# 125 1 [Poly(x^8 + 4x^7 + 7x^6 + 7x^5 + 6x^3 + 2x + 3, GF(2^3))] [1]
# 126 5 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^2 + 7x + 2, GF(2^3))] [2, 1, 1, 1, 1]
# 127 5 [Poly(x, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^4 + x^3 + 5x^2 + 1, GF(2^3))] [1, 1, 1, 1, 1]
# 128 1 [Poly(x^8 + 3x^7 + 3x^6 + 4x^5 + 3x^4 + 5x^3 + 4x^2 + 2, GF(2^3))] [1]
# 129 4 [Poly(x + 2, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 2x^3 + 6x^2 + 2x + 3, GF(2^3))] [1, 1, 1, 1]
# 130 3 [Poly(x, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^5 + 5x^3 + 7x^2 + 7, GF(2^3))] [1, 1, 1]
# 131 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + 4x^6 + x^5 + 4x^4 + x^3 + 4x + 2, GF(2^3))] [1, 1]
# 132 4 [Poly(x + 1, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 5x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 7x + 6, GF(2^3))] [1, 1, 1, 1]
# 133 2 [Poly(x + 2, GF(2^3)), Poly(x^7 + 7x^6 + 3x^5 + 3x^4 + 6x^3 + 4x^2 + x + 6, GF(2^3))] [1, 1]
# 134 2 [Poly(x + 4, GF(2^3)), Poly(x^7 + 2x^6 + 2x^5 + 2x^4 + 4x^3 + 3x^2 + 7x + 2, GF(2^3))] [1, 1]
# 135 5 [Poly(x, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 2x + 4, GF(2^3))] [1, 1, 1, 1, 2]
# 136 3 [Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + 3x^5 + 5x^3 + 4x^2 + 4x + 4, GF(2^3))] [1, 1, 1]
# 137 3 [Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^2 + 5x + 2, GF(2^3)), Poly(x^4 + x^3 + 6x^2 + 6x + 4, GF(2^3))] [1, 1, 1]
# 138 4 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 7x + 3, GF(2^3)), Poly(x^3 + x^2 + 2, GF(2^3))] [2, 1, 1, 1]
# 139 2 [Poly(x + 4, GF(2^3)), Poly(x^7 + 2x^6 + 4x^5 + 4x^4 + 5x^3 + 2x^2 + 7x + 2, GF(2^3))] [1, 1]
# 140 1 [Poly(x^8 + 6x^7 + 4x^6 + 4x^5 + 6x^4 + 5x^3 + 7x + 6, GF(2^3))] [1]
# 141 3 [Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 3x^5 + 4x^4 + 3x^3 + 7x^2 + 2x + 7, GF(2^3))] [1, 1, 1]
# 142 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 3x^6 + 2x^5 + 2x^4 + 7x^3 + 7x^2 + 2x + 3, GF(2^3))] [1, 1]
# 143 1 [Poly(x^8 + x^7 + 4x^6 + 5x^5 + 4x^4 + 2x^3 + 2x^2 + 2x + 2, GF(2^3))] [1]
# 144 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^5 + 4x^4 + 4x^3 + 2x^2 + 2, GF(2^3))] [1, 1, 1]
# 145 3 [Poly(x^2 + x + 3, GF(2^3)), Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^4 + 3x^3 + 7x^2 + 7x + 6, GF(2^3))] [1, 1, 1]
# 146 2 [Poly(x, GF(2^3)), Poly(x^7 + 3x^6 + 2x^5 + 2x^4 + 5x^3 + 3x + 7, GF(2^3))] [1, 1]
# 147 3 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x^6 + 6x^5 + 6x^2 + 6, GF(2^3))] [1, 1, 1]
# 148 2 [Poly(x + 3, GF(2^3)), Poly(x^6 + 7x^5 + 4x^4 + 4x^3 + x^2 + 4x + 1, GF(2^3))] [2, 1]
# 149 4 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^2 + 7x + 3, GF(2^3)), Poly(x^4 + 6x^3 + 3x^2 + x + 3, GF(2^3))] [1, 1, 1, 1]
# 150 1 [Poly(x^8 + 7x^7 + 5x^6 + 6x^5 + x^4 + 2x^3 + 5, GF(2^3))] [1]
# 151 2 [Poly(x^3 + 2x^2 + 6x + 2, GF(2^3)), Poly(x^5 + 7x^4 + 2x^3 + 6x^2 + x + 5, GF(2^3))] [1, 1]
# 152 4 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^3 + x^2 + 6, GF(2^3))] [2, 1, 2, 1]
# 153 3 [Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^4 + 2x^3 + 3x + 5, GF(2^3))] [3, 1, 1]
# 154 3 [Poly(x^2 + x + 5, GF(2^3)), Poly(x^2 + 3x + 7, GF(2^3)), Poly(x^4 + 3x^3 + 2x^2 + x + 7, GF(2^3))] [1, 1, 1]
# 155 2 [Poly(x + 6, GF(2^3)), Poly(x^7 + 4x^6 + 5x^5 + x^3 + 3x^2 + 5x + 6, GF(2^3))] [1, 1]
# 156 3 [Poly(x + 4, GF(2^3)), Poly(x^3 + 3x^2 + x + 4, GF(2^3)), Poly(x^4 + 2x^3 + 2x^2 + 7x + 3, GF(2^3))] [1, 1, 1]
# 157 1 [Poly(x^8 + 6x^6 + 3x^4 + 2x^3 + 4x^2 + 4, GF(2^3))] [1]
# 158 3 [Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + 7x^5 + 7x^4 + 5x^3 + 3x^2 + 7x + 2, GF(2^3))] [1, 1, 1]
# 159 5 [Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^3 + 6x^2 + 5x + 6, GF(2^3))] [1, 1, 1, 1, 1]
# 160 4 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^5 + 4x^4 + 5x^3 + 3x^2 + 7x + 2, GF(2^3))] [1, 1, 1, 1]
# 161 3 [Poly(x + 4, GF(2^3)), Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^3 + 6x^2 + 7x + 2, GF(2^3))] [1, 2, 1]
# 162 2 [Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^6 + 3x^5 + 5x^3 + x^2 + 5x + 7, GF(2^3))] [1, 1]
# 163 2 [Poly(x^3 + x^2 + 3x + 7, GF(2^3)), Poly(x^5 + 3x^4 + 3x^3 + 7x + 1, GF(2^3))] [1, 1]
# 164 3 [Poly(x + 1, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 2x^3 + 7x^2 + 4x + 4, GF(2^3))] [2, 1, 1]
# 165 4 [Poly(x + 1, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^3 + 4x^2 + 5x + 6, GF(2^3)), Poly(x^3 + 6x^2 + 7x + 2, GF(2^3))] [1, 1, 1, 1]
# 166 4 [Poly(x, GF(2^3)), Poly(x^2 + 5x + 2, GF(2^3)), Poly(x^2 + 7x + 4, GF(2^3)), Poly(x^3 + 2x^2 + x + 7, GF(2^3))] [1, 1, 1, 1]
# 167 1 [Poly(x^8 + 6x^7 + 5x^4 + 3x^3 + 4x^2 + 5x + 3, GF(2^3))] [1]
# 168 3 [Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^2 + 7x + 4, GF(2^3)), Poly(x^4 + 2x^3 + 2x^2 + 6, GF(2^3))] [1, 1, 1]
# 169 3 [Poly(x + 3, GF(2^3)), Poly(x^3 + x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 6x^3 + x^2 + 3x + 4, GF(2^3))] [1, 1, 1]
# 170 1 [Poly(x^8 + 6x^7 + 3x^5 + x^4 + 2x^3 + 4x^2 + 7x + 3, GF(2^3))] [1]
# 171 3 [Poly(x, GF(2^3)), Poly(x^3 + 5x^2 + 4x + 6, GF(2^3)), Poly(x^4 + 7x^3 + 4x^2 + x + 4, GF(2^3))] [1, 1, 1]
# 172 2 [Poly(x + 2, GF(2^3)), Poly(x^6 + x^5 + 3x^3 + 7x^2 + 3x + 2, GF(2^3))] [2, 1]
# 173 2 [Poly(x^4 + 2x^3 + 7x^2 + 7x + 2, GF(2^3)), Poly(x^4 + 6x^3 + 7x + 3, GF(2^3))] [1, 1]
# 174 5 [Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 3x + 4, GF(2^3))] [1, 1, 1, 1, 1]
# 175 3 [Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^3 + 7x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 3x + 1, GF(2^3))] [1, 1, 1]
# 176 3 [Poly(x, GF(2^3)), Poly(x^3 + 5x^2 + 3x + 3, GF(2^3)), Poly(x^4 + 3x^3 + x^2 + 3x + 4, GF(2^3))] [1, 1, 1]
# 177 2 [Poly(x^3 + 3x^2 + 3, GF(2^3)), Poly(x^5 + 3x^4 + 2x^3 + 2x^2 + 2x + 6, GF(2^3))] [1, 1]
# 178 2 [Poly(x + 4, GF(2^3)), Poly(x^7 + 6x^6 + x^5 + 3x^4 + 6x^3 + 5x^2 + 4x + 7, GF(2^3))] [1, 1]
# 179 4 [Poly(x + 4, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^4 + 3x^2 + x + 6, GF(2^3))] [1, 1, 1, 1]
# 180 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + 5x + 6, GF(2^3)), Poly(x^4 + 5x^2 + x + 1, GF(2^3))] [2, 1, 1]
# 181 3 [Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^5 + 3x^4 + 7x^2 + 4x + 5, GF(2^3))] [2, 1, 1]
# 182 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 2x^6 + x^5 + 2x^4 + 5x^3 + 7x^2 + 3x + 5, GF(2^3))] [1, 1]
# 183 4 [Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^3 + 7x^2 + 5x + 4, GF(2^3)), Poly(x^3 + 7x^2 + 7x + 5, GF(2^3))] [1, 1, 1, 1]
# 184 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + x^6 + 4x^5 + x^4 + x^3 + 3x^2 + 3x + 5, GF(2^3))] [1, 1]
# 185 5 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 5x + 6, GF(2^3)), Poly(x^3 + 2x^2 + 5x + 5, GF(2^3))] [1, 1, 1, 1, 1]
# 186 2 [Poly(x + 7, GF(2^3)), Poly(x^7 + 4x^6 + 7x^5 + 4x^4 + 6x^3 + 2x^2 + 1, GF(2^3))] [1, 1]
# 187 2 [Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^6 + 3x^5 + 5x^4 + 4x^3 + 4x^2 + 3, GF(2^3))] [1, 1]
# 188 4 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 2x + 7, GF(2^3)), Poly(x^4 + x^3 + 2x^2 + 4x + 3, GF(2^3))] [1, 1, 1, 1]
# 189 3 [Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^6 + 6x^5 + 5x^4 + 2x^3 + x^2 + 3x + 5, GF(2^3))] [1, 1, 1]
# 190 5 [Poly(x + 2, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + x + 3, GF(2^3)), Poly(x^3 + 7x^2 + x + 2, GF(2^3))] [1, 1, 1, 1, 1]
# 191 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + x + 1, GF(2^3)), Poly(x^5 + 4x^4 + 5x^3 + 4x^2 + 3x + 3, GF(2^3))] [1, 1, 1]
# 192 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 7x + 2, GF(2^3)), Poly(x^5 + x^4 + 3x^3 + x^2 + 5, GF(2^3))] [1, 1, 1]
# 193 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + 4x + 4, GF(2^3)), Poly(x^5 + x^4 + 7x^2 + 7x + 7, GF(2^3))] [1, 1, 1]
# 194 2 [Poly(x^2 + 4x + 6, GF(2^3)), Poly(x^6 + 4x^5 + 4x^4 + 6x^3 + 2x^2 + 2x + 2, GF(2^3))] [1, 1]
# 195 2 [Poly(x + 3, GF(2^3)), Poly(x^7 + 2x^6 + 4x^4 + 3x^3 + 7x^2 + 2x + 3, GF(2^3))] [1, 1]
# 196 1 [Poly(x^8 + 3x^7 + x^6 + 3x^5 + 7x^4 + 2x + 7, GF(2^3))] [1]
# 197 3 [Poly(x + 4, GF(2^3)), Poly(x^3 + 3x^2 + 3x + 6, GF(2^3)), Poly(x^4 + 7x^3 + x^2 + 4x + 7, GF(2^3))] [1, 1, 1]
# 198 2 [Poly(x + 5, GF(2^3)), Poly(x^6 + 6x^4 + 3x + 6, GF(2^3))] [2, 1]
# 199 4 [Poly(x + 7, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^2 + 4x + 3, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3))] [2, 1, 1, 1]
# 200 3 [Poly(x + 7, GF(2^3)), Poly(x^3 + 4x^2 + 1, GF(2^3)), Poly(x^4 + 2x^3 + 2x^2 + 5x + 5, GF(2^3))] [1, 1, 1]
# 201 4 [Poly(x + 1, GF(2^3)), Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^2 + 7x + 3, GF(2^3)), Poly(x^3 + 2x^2 + 7, GF(2^3))] [1, 1, 1, 1]
# 202 3 [Poly(x, GF(2^3)), Poly(x^3 + x^2 + 6x + 1, GF(2^3)), Poly(x^4 + 4x^3 + 6x^2 + 4x + 1, GF(2^3))] [1, 1, 1]
# 203 4 [Poly(x, GF(2^3)), Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^3 + x^2 + 3x + 2, GF(2^3))] [1, 1, 1, 1]
# 204 3 [Poly(x^2 + 6x + 2, GF(2^3)), Poly(x^3 + 3x + 4, GF(2^3)), Poly(x^3 + 2x^2 + x + 1, GF(2^3))] [1, 1, 1]
# 205 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + x + 7, GF(2^3)), Poly(x^5 + 7x^4 + 3x^3 + 4x^2 + 3x + 5, GF(2^3))] [1, 1, 1]
# 206 2 [Poly(x + 4, GF(2^3)), Poly(x^7 + 4x^5 + x^4 + 3, GF(2^3))] [1, 1]
# 207 4 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^4 + 6x + 5, GF(2^3))] [1, 1, 1, 1]
# 208 4 [Poly(x + 3, GF(2^3)), Poly(x^2 + 4x + 6, GF(2^3)), Poly(x^2 + 5x + 2, GF(2^3)), Poly(x^2 + 5x + 3, GF(2^3))] [2, 1, 1, 1]
# 209 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 7x + 2, GF(2^3)), Poly(x^5 + 2x^4 + 7x^3 + 2x^2 + 4x + 7, GF(2^3))] [1, 1, 1]
# 210 1 [Poly(x^8 + 4x^7 + 3x^6 + 2x^5 + 2x^4 + 3x^3 + 2x^2 + 3x + 6, GF(2^3))] [1]
# 211 3 [Poly(x, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 4x^5 + 4x^4 + x^3 + 4x^2 + 4x + 3, GF(2^3))] [1, 1, 1]
# 212 1 [Poly(x^8 + 6x^7 + 4x^6 + 5x^5 + 7x^4 + 5x^3 + 7x^2 + 7x + 7, GF(2^3))] [1]
# 213 2 [Poly(x + 3, GF(2^3)), Poly(x^6 + x^4 + 3x^3 + 2x^2 + 3x + 5, GF(2^3))] [2, 1]
# 214 5 [Poly(x + 1, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + x + 1, GF(2^3)), Poly(x^3 + 4x + 6, GF(2^3))] [1, 1, 1, 1, 1]
# 215 6 [Poly(x, GF(2^3)), Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^3 + 2x + 4, GF(2^3))] [1, 1, 1, 1, 1, 1]
# 216 3 [Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + 6x^5 + 7x^4 + x^3 + 7x^2 + 5x + 5, GF(2^3))] [1, 1, 1]
# 217 3 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^6 + 4x^5 + x^4 + 2x^3 + 2x^2 + 7x + 7, GF(2^3))] [1, 1, 1]
# 218 2 [Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^6 + 4x^5 + 5x^4 + x + 6, GF(2^3))] [1, 1]
# 219 3 [Poly(x + 1, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 4x^5 + 4x^4 + 7x^3 + 7x^2 + 5x + 1, GF(2^3))] [1, 1, 1]
# 220 1 [Poly(x^8 + 4x^7 + 3x^5 + 7x^4 + 4x^3 + 6x^2 + x + 6, GF(2^3))] [1]
# 221 2 [Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^6 + 7x^5 + 6x^4 + 5x^3 + 5x^2 + 5x + 1, GF(2^3))] [1, 1]
# 222 4 [Poly(x, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^2 + 7x + 3, GF(2^3))] [2, 2, 1, 1]
# 223 3 [Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^6 + 3x^4 + 3x^3 + x^2 + 2x + 6, GF(2^3))] [1, 1, 1]
# 224 2 [Poly(x + 2, GF(2^3)), Poly(x^7 + 2x^6 + 2x^5 + 2x^4 + x^3 + 3x^2 + 2x + 7, GF(2^3))] [1, 1]
# 225 1 [Poly(x^8 + 4x^7 + 4x^6 + 4x^5 + 6x^4 + x^2 + 7x + 7, GF(2^3))] [1]
# 226 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^5 + 3x^4 + 4x^3 + 2x^2 + 4x + 4, GF(2^3))] [1, 1, 1]
# 227 4 [Poly(x, GF(2^3)), Poly(x + 1, GF(2^3)), Poly(x^2 + 2x + 4, GF(2^3)), Poly(x^4 + 5x^3 + x^2 + 4x + 4, GF(2^3))] [1, 1, 1, 1]
# 228 4 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^2 + 4x + 4, GF(2^3)), Poly(x^4 + x^3 + x^2 + 3, GF(2^3))] [1, 1, 1, 1]
# 229 4 [Poly(x, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3))] [2, 1, 1, 2]
# 230 3 [Poly(x, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^4 + 2x^3 + 2x^2 + 5x + 5, GF(2^3))] [2, 1, 1]
# 231 3 [Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^6 + 5x^5 + 7x^4 + 6x^2 + 4x + 6, GF(2^3))] [1, 1, 1]
# 232 4 [Poly(x + 7, GF(2^3)), Poly(x^2 + 3x + 4, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^3 + 3x^2 + 6x + 5, GF(2^3))] [1, 1, 1, 1]
# 233 1 [Poly(x^8 + 5x^7 + 6x^6 + 5x^4 + 6x^3 + 7x^2 + 4, GF(2^3))] [1]
# 234 4 [Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^5 + 6x^4 + 5x^3 + 3x^2 + 7x + 1, GF(2^3))] [1, 1, 1, 1]
# 235 5 [Poly(x, GF(2^3)), Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^4 + x^2 + 5x + 7, GF(2^3))] [1, 1, 1, 1, 1]
# 236 1 [Poly(x^8 + 4x^7 + 4x^6 + 6x^5 + 7x^4 + 7x^3 + x^2 + 2x + 3, GF(2^3))] [1]
# 237 1 [Poly(x^8 + x^7 + 3x^6 + 3x^5 + 4x^4 + 2x^3 + 7x + 6, GF(2^3))] [1]
# 238 4 [Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + x + 7, GF(2^3)), Poly(x^4 + 5x^3 + 3x^2 + 3x + 2, GF(2^3))] [1, 1, 1, 1]
# 239 4 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x^3 + 6x^2 + 3x + 5, GF(2^3)), Poly(x^3 + 7x^2 + 7x + 4, GF(2^3))] [1, 1, 1, 1]
# 240 2 [Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^6 + x^5 + 3x^4 + 6x^2 + 5x + 4, GF(2^3))] [1, 1]
# 241 4 [Poly(x + 3, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 4x + 4, GF(2^3)), Poly(x^4 + 7x^3 + 2x^2 + 5x + 7, GF(2^3))] [1, 1, 1, 1]
# 242 2 [Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^6 + 4x^4 + 3x^3 + 4x^2 + x + 4, GF(2^3))] [1, 1]
# 243 4 [Poly(x + 1, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + x + 1, GF(2^3)), Poly(x^4 + 4x^3 + 5x^2 + 5, GF(2^3))] [1, 1, 1, 1]
# 244 3 [Poly(x, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x^6 + 7x^5 + 3x^4 + 3x^3 + 3x^2 + 2x + 6, GF(2^3))] [1, 1, 1]
# 245 4 [Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + 4x + 4, GF(2^3)), Poly(x^4 + 4x^3 + 6x^2 + 5x + 2, GF(2^3))] [1, 1, 1, 1]
# 246 2 [Poly(x^2 + x + 3, GF(2^3)), Poly(x^6 + 4x^5 + x^4 + 4x^3 + 6x^2 + 7x + 6, GF(2^3))] [1, 1]
# 247 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + 6x + 2, GF(2^3)), Poly(x^5 + 4x^4 + 3x^3 + 6x^2 + 5x + 7, GF(2^3))] [1, 1, 1]
# 248 5 [Poly(x + 2, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^2 + 4x + 6, GF(2^3))] [1, 1, 1, 1, 1]
# 249 2 [Poly(x, GF(2^3)), Poly(x^7 + 5x^6 + 6x^4 + 6x^3 + 4x^2 + 2x + 1, GF(2^3))] [1, 1]
# 250 4 [Poly(x, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 6x^3 + 5x^2 + 4, GF(2^3))] [1, 1, 1, 1]
# 251 2 [Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^6 + 6x^5 + x^4 + 3x^3 + 4x^2 + x + 7, GF(2^3))] [1, 1]
# 252 1 [Poly(x^8 + x^6 + 4x^5 + x^4 + 6x^3 + x^2 + 6, GF(2^3))] [1]
# 253 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 6x^6 + 7x^4 + 2x^3 + 5x^2 + 5x + 5, GF(2^3))] [1, 1]
# 254 5 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^3 + 2x + 1, GF(2^3))] [1, 1, 1, 1, 1]
# 255 2 [Poly(x + 6, GF(2^3)), Poly(x^7 + 6x^6 + 2x^5 + 5x^4 + 6x^2 + x + 6, GF(2^3))] [1, 1]
# 256 4 [Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^3 + x^2 + 5x + 2, GF(2^3))] [2, 1, 2, 1]
# 257 3 [Poly(x, GF(2^3)), Poly(x^2 + 2x + 7, GF(2^3)), Poly(x^5 + 6x^4 + 5x^3 + 3x^2 + 4x + 3, GF(2^3))] [1, 1, 1]
# 258 4 [Poly(x + 4, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^5 + x^4 + 5x^3 + 5x^2 + 1, GF(2^3))] [1, 1, 1, 1]
# 259 1 [Poly(x^8 + 4x^7 + 6x^6 + 3x^5 + 3x^4 + x^3 + x^2 + x + 7, GF(2^3))] [1]
# 260 2 [Poly(x^3 + x^2 + 6, GF(2^3)), Poly(x^5 + 7x^4 + 7x^3 + 7x^2 + 5x + 5, GF(2^3))] [1, 1]
# 261 5 [Poly(x, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^2 + 2x + 2, GF(2^3)), Poly(x^3 + 4x^2 + x + 1, GF(2^3))] [1, 1, 1, 1, 1]
# 262 3 [Poly(x, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^3 + 6x^2 + 5x + 6, GF(2^3))] [2, 3, 1]
# 263 2 [Poly(x^2 + 2x + 2, GF(2^3)), Poly(x^6 + 4x^5 + 4x^4 + 2x^3 + 6x^2 + 3, GF(2^3))] [1, 1]
# 264 3 [Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x^6 + x^5 + x^4 + 7x^2 + 5x + 7, GF(2^3))] [1, 1, 1]
# 265 3 [Poly(x + 4, GF(2^3)), Poly(x^3 + 7x^2 + 6x + 1, GF(2^3)), Poly(x^4 + 3x^3 + 2x^2 + 5x + 2, GF(2^3))] [1, 1, 1]
# 266 3 [Poly(x + 3, GF(2^3)), Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^5 + 4x^3 + 6x^2 + 2, GF(2^3))] [1, 1, 1]
# 267 3 [Poly(x^2 + 5x + 2, GF(2^3)), Poly(x^3 + 2x^2 + x + 7, GF(2^3)), Poly(x^3 + 5x^2 + 2x + 2, GF(2^3))] [1, 1, 1]
# 268 3 [Poly(x, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 3x^5 + 7x^4 + 7x^3 + 5x^2 + 2x + 2, GF(2^3))] [1, 1, 1]
# 269 3 [Poly(x, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^5 + 3x^4 + 4x^3 + 4x^2 + 7x + 1, GF(2^3))] [1, 2, 1]
# 270 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^5 + 2x^4 + 3x^3 + 2x^2 + x + 1, GF(2^3))] [1, 1, 1]
# 271 3 [Poly(x + 3, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 6x^5 + 3x^4 + 7x^3 + 7x + 5, GF(2^3))] [1, 1, 1]
# 272 3 [Poly(x, GF(2^3)), Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^5 + 7x^4 + 4x^3 + 6x^2 + 3x + 4, GF(2^3))] [1, 1, 1]
# 273 4 [Poly(x + 6, GF(2^3)), Poly(x^2 + x + 3, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^3 + 2x^2 + 1, GF(2^3))] [1, 1, 1, 1]
# 274 2 [Poly(x + 5, GF(2^3)), Poly(x^6 + 3x^5 + x^4 + 7x^3 + 3x^2 + 3x + 3, GF(2^3))] [2, 1]
# 275 3 [Poly(x + 5, GF(2^3)), Poly(x^3 + x^2 + 6x + 4, GF(2^3)), Poly(x^4 + 7x^3 + 7x^2 + 4x + 1, GF(2^3))] [1, 1, 1]
# 276 5 [Poly(x, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 4x + 1, GF(2^3)), Poly(x^3 + 5x^2 + 2x + 7, GF(2^3))] [1, 1, 1, 1, 1]
# 277 5 [Poly(x + 1, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^4 + 2x^3 + 2, GF(2^3))] [1, 1, 1, 1, 1]
# 278 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + 5x^6 + 3x^5 + 3x^4 + x^3 + 7x + 4, GF(2^3))] [1, 1]
# 279 4 [Poly(x + 4, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^3 + 7x^2 + 4x + 6, GF(2^3))] [2, 1, 1, 1]
# 280 3 [Poly(x + 2, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x^6 + 3x^5 + 4x^4 + 7x^3 + 7x^2 + 2x + 3, GF(2^3))] [1, 1, 1]
# 281 3 [Poly(x + 3, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^6 + 3x^5 + 4x^4 + 3x^2 + 3x + 2, GF(2^3))] [1, 1, 1]
# 282 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + 2x^6 + x^5 + 4x^4 + 5x^3 + 5x^2 + 5x + 7, GF(2^3))] [1, 1]
# 283 4 [Poly(x, GF(2^3)), Poly(x^2 + 6x + 1, GF(2^3)), Poly(x^2 + 6x + 5, GF(2^3)), Poly(x^3 + x^2 + 3x + 6, GF(2^3))] [1, 1, 1, 1]
# 284 2 [Poly(x + 3, GF(2^3)), Poly(x^7 + 3x^6 + 2x^5 + x^4 + x^3 + x^2 + 7x + 2, GF(2^3))] [1, 1]
# 285 1 [Poly(x^8 + 3x^7 + 3x^6 + 7x^4 + 2x^3 + 6, GF(2^3))] [1]
# 286 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + x^5 + x^3 + 6x^2 + 4x + 2, GF(2^3))] [1, 1]
# 287 3 [Poly(x + 7, GF(2^3)), Poly(x^3 + 3x^2 + 7x + 3, GF(2^3)), Poly(x^4 + 6x^3 + 3x^2 + 5x + 3, GF(2^3))] [1, 1, 1]
# 288 3 [Poly(x + 6, GF(2^3)), Poly(x^2 + 3x + 4, GF(2^3)), Poly(x^5 + 4x^4 + 7x^3 + 3x + 2, GF(2^3))] [1, 1, 1]
# 289 1 [Poly(x^8 + 5x^7 + 4x^6 + 7x^5 + 6x^4 + 6x^3 + 5x^2 + 6x + 6, GF(2^3))] [1]
# 290 2 [Poly(x + 2, GF(2^3)), Poly(x^7 + 6x^6 + 5x^4 + 4x^3 + 5x^2 + 6x + 6, GF(2^3))] [1, 1]
# 291 3 [Poly(x + 7, GF(2^3)), Poly(x^2 + 7x + 5, GF(2^3)), Poly(x^5 + 4x^3 + 6x^2 + 3x + 5, GF(2^3))] [1, 1, 1]
# 292 3 [Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 3x^5 + 7x^4 + 6x^3 + 6x^2 + 4x + 6, GF(2^3))] [1, 1, 1]
# 293 2 [Poly(x^4 + 5x^3 + 2x^2 + 2x + 6, GF(2^3)), Poly(x^4 + 5x^3 + 3x^2 + 2x + 2, GF(2^3))] [1, 1]
# 294 3 [Poly(x, GF(2^3)), Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^5 + 3x^4 + 4x^2 + 7, GF(2^3))] [1, 1, 1]
# 295 2 [Poly(x + 2, GF(2^3)), Poly(x^7 + 2x^6 + 5x^5 + 6x^4 + 2x^2 + x + 2, GF(2^3))] [1, 1]
# 296 2 [Poly(x^4 + 7x^3 + 4x^2 + 7x + 3, GF(2^3)), Poly(x^4 + 7x^3 + 5x^2 + 3x + 3, GF(2^3))] [1, 1]
# 297 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + 6x + 6, GF(2^3)), Poly(x^5 + 5x^4 + 6x^2 + 5, GF(2^3))] [1, 1, 1]
# 298 4 [Poly(x, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^4 + x^3 + x^2 + x + 1, GF(2^3))] [1, 1, 1, 1]
# 299 1 [Poly(x^8 + 4x^7 + 5x^6 + x^5 + 3x^4 + 4x^3 + 3x^2 + 2x + 6, GF(2^3))] [1]
# 300 3 [Poly(x + 3, GF(2^3)), Poly(x^2 + 2x + 7, GF(2^3)), Poly(x^4 + 3x^3 + 5x + 1, GF(2^3))] [2, 1, 1]
# 301 5 [Poly(x + 1, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^3 + x^2 + 2x + 1, GF(2^3))] [1, 1, 1, 2, 1]
# 302 4 [Poly(x^2 + x + 7, GF(2^3)), Poly(x^2 + 4x + 4, GF(2^3)), Poly(x^2 + 4x + 6, GF(2^3)), Poly(x^2 + 5x + 6, GF(2^3))] [1, 1, 1, 1]
# 303 3 [Poly(x + 3, GF(2^3)), Poly(x^2 + 3x + 4, GF(2^3)), Poly(x^5 + 6x^4 + 5x^3 + 7x^2 + 5x + 3, GF(2^3))] [1, 1, 1]
# 304 3 [Poly(x + 7, GF(2^3)), Poly(x^3 + 6x^2 + 7x + 2, GF(2^3)), Poly(x^4 + x^3 + 6x^2 + 6x + 4, GF(2^3))] [1, 1, 1]
# 305 2 [Poly(x + 5, GF(2^3)), Poly(x^7 + 7x^5 + 6x^4 + 2x^3 + 7x^2 + 6x + 5, GF(2^3))] [1, 1]
# 306 3 [Poly(x, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 5x^5 + 3x^4 + 7x^3 + 4x + 2, GF(2^3))] [1, 1, 1]
# 307 3 [Poly(x + 2, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^6 + 2x^5 + 4x^4 + x^3 + 5x^2 + 4x + 3, GF(2^3))] [1, 1, 1]
# 308 3 [Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x^5 + 2x^4 + 7x^3 + 7x^2 + 4x + 6, GF(2^3))] [1, 2, 1]
# 309 3 [Poly(x + 3, GF(2^3)), Poly(x^2 + 3x + 6, GF(2^3)), Poly(x^5 + 6x^4 + x^3 + x^2 + x + 2, GF(2^3))] [1, 1, 1]
# 310 3 [Poly(x, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 2x^5 + 4x^4 + 4x^3 + 3x^2 + 6, GF(2^3))] [1, 1, 1]
# 311 3 [Poly(x + 5, GF(2^3)), Poly(x^2 + x + 1, GF(2^3)), Poly(x^4 + 2x^3 + 5x^2 + 5x + 4, GF(2^3))] [2, 1, 1]
# 312 4 [Poly(x + 2, GF(2^3)), Poly(x^2 + x + 5, GF(2^3)), Poly(x^2 + 3x + 7, GF(2^3)), Poly(x^2 + 4x + 6, GF(2^3))] [2, 1, 1, 1]
# 313 5 [Poly(x, GF(2^3)), Poly(x + 1, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^3 + 6x + 1, GF(2^3))] [1, 1, 1, 1, 1]
# 314 3 [Poly(x + 1, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^4 + 2x^3 + 7x^2 + 6x + 1, GF(2^3))] [1, 3, 1]
# 315 2 [Poly(x + 1, GF(2^3)), Poly(x^7 + 5x^6 + x^5 + 5x^3 + x^2 + 7x + 1, GF(2^3))] [1, 1]
# 316 3 [Poly(x + 5, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^2 + 6x + 2, GF(2^3))] [1, 5, 1]
# 317 2 [Poly(x, GF(2^3)), Poly(x^6 + 5x^5 + 4x^4 + 6x^3 + 6x + 5, GF(2^3))] [2, 1]
# 318 1 [Poly(x^8 + 2x^7 + 6x^6 + 7x^5 + 4x^4 + 3x^3 + 5x^2 + 2x + 3, GF(2^3))] [1]
# 319 3 [Poly(x^2 + x + 7, GF(2^3)), Poly(x^2 + 2x + 1, GF(2^3)), Poly(x^4 + 3x^3 + 4x^2 + 6x + 4, GF(2^3))] [1, 1, 1]
# 320 1 [Poly(x^8 + 5x^6 + 4x^5 + 4x^4 + 7x^3 + 3x^2 + x + 7, GF(2^3))] [1]
# 321 3 [Poly(x + 4, GF(2^3)), Poly(x^3 + 2x^2 + 7, GF(2^3)), Poly(x^4 + x^3 + 4x^2 + 2x + 2, GF(2^3))] [1, 1, 1]
# 322 1 [Poly(x^8 + 7x^7 + 3x^6 + 4x^5 + 7x^4 + 7x^3 + 7x^2 + 3x + 4, GF(2^3))] [1]
# 323 3 [Poly(x + 3, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 6x^5 + 5x^4 + x^2 + x + 7, GF(2^3))] [1, 1, 1]
# 324 4 [Poly(x + 1, GF(2^3)), Poly(x + 4, GF(2^3)), Poly(x^2 + 5x + 3, GF(2^3)), Poly(x^4 + 7x + 2, GF(2^3))] [1, 1, 1, 1]
# 325 3 [Poly(x, GF(2^3)), Poly(x^2 + 6x + 2, GF(2^3)), Poly(x^4 + 4x^3 + 3x^2 + 2, GF(2^3))] [2, 1, 1]
# 326 5 [Poly(x, GF(2^3)), Poly(x + 2, GF(2^3)), Poly(x + 5, GF(2^3)), Poly(x + 6, GF(2^3)), Poly(x^4 + 4x^3 + 4x^2 + 4x + 2, GF(2^3))] [1, 1, 1, 1, 1]
# 327 3 [Poly(x + 6, GF(2^3)), Poly(x + 7, GF(2^3)), Poly(x^6 + 4x^5 + 3x^4 + x^3 + 7x^2 + 5x + 4, GF(2^3))] [1, 1, 1]
# 328 2 [Poly(x^3 + 3x^2 + 6x + 6, GF(2^3)), Poly(x^5 + 6x^4 + 5x^3 + 6x + 7, GF(2^3))] [1, 1]
# 329 3 [Poly(x + 2, GF(2^3)), Poly(x^3 + 2x^2 + 1, GF(2^3)), Poly(x^4 + 6x^3 + 3x + 3, GF(2^3))] [1, 1, 1]
# 330 4 [Poly(x + 2, GF(2^3)), Poly(x + 3, GF(2^3)), Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^4 + 4x^3 + 4x^2 + 7x + 7, GF(2^3))] [1, 1, 1, 1]
# 331 1 [Poly(x^8 + 4x^7 + 5x^6 + 2x^5 + 3x^4 + 5x^3 + 4x^2 + 6, GF(2^3))] [1]
# 332 2 [Poly(x^2 + 5x + 7, GF(2^3)), Poly(x^6 + 4x^5 + 4x^4 + 7x^3 + 2x + 5, GF(2^3))] [1, 1]
# 333 3 [Poly(x + 2, GF(2^3)), Poly(x^2 + 3x + 5, GF(2^3)), Poly(x^5 + 3x^4 + 4x^3 + x + 4, GF(2^3))] [1, 1, 1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 characteristic_poly_2(public)
#
# Cell In[49], line 21, in characteristic_poly_2(public, count)
#      17         g_j += FIELD.Random((1)) * g
#      19 g_ij = np.linalg.inv(g_i) * g_j
# ---> 21 polys, coeffs = g_ij.characteristic_poly().factors()
#      22 if len(coeffs) == 2:
#      23     first_kernel = polys[0](g_ij).null_space()
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:1972, in FieldArray.characteristic_poly(self)
#    1970     return _characteristic_poly_element(self)
#    1971 elif self.ndim == 2:
# -> 1972     return _characteristic_poly_matrix(self)
#    1973 else:
#    1974     raise ValueError(
#    1975         f"The array must be either 0-D to return the characteristic polynomial of a single element "
#    1976         f"or 2-D to return the characteristic polynomial of a square matrix, not have shape {self.shape}."
#    1977     )
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:2430, in _characteristic_poly_matrix(A)
#    2427         else:
#    2428             P[i, j] = Poly([-A[i, j]], field=field)
# -> 2430 return _poly_det(P)
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:2376, in _poly_det(A)
#    2374 for i in range(n):
#    2375     idxs = np.delete(np.arange(n), i)
# -> 2376     cofactor = _poly_det(A[1:, idxs])
#    2377     if i % 2 == 0:
#    2378         det += A[0, i] * cofactor
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:2376, in _poly_det(A)
#    2374 for i in range(n):
#    2375     idxs = np.delete(np.arange(n), i)
# -> 2376     cofactor = _poly_det(A[1:, idxs])
#    2377     if i % 2 == 0:
#    2378         det += A[0, i] * cofactor
#
#     [... skipping similar frames: _poly_det at line 2376 (2 times)]
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:2376, in _poly_det(A)
#    2374 for i in range(n):
#    2375     idxs = np.delete(np.arange(n), i)
# -> 2376     cofactor = _poly_det(A[1:, idxs])
#    2377     if i % 2 == 0:
#    2378         det += A[0, i] * cofactor
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:2378, in _poly_det(A)
#    2376 cofactor = _poly_det(A[1:, idxs])
#    2377 if i % 2 == 0:
# -> 2378     det += A[0, i] * cofactor
#    2379 else:
#    2380     det -= A[0, i] * cofactor
#
# File ~/.local/lib/python3.14/site-packages/galois/_polys/_poly.py:1196, in Poly.__add__(self, other)
#    1194     a = _convert_to_coeffs(self, self.field)
#    1195     b = _convert_to_coeffs(other, self.field)
# -> 1196     c = _dense.add_jit(self.field)(a, b)
#    1197     output = Poly(c, field=self.field)
#    1199 return output
#
# File ~/.local/lib/python3.14/site-packages/galois/_polys/_dense.py:31, in add_jit.__call__(self, a, b)
#      28 dtype = a.dtype
#      30 if self.field.ufunc_mode != "python-calculate":
# ---> 31     r = self.jit(a.astype(np.int64), b.astype(np.int64))
#      32     r = r.astype(dtype)
#      33 else:
#
# File ~/.local/lib/python3.14/site-packages/galois/_domains/_function.py:95, in Function.jit(self)
#      92     func = numba.jit(self._SIGNATURE.signature, parallel=self._PARALLEL, nopython=True)(self.implementation)
#      93     self._CACHE[self.key_1][self.key_2] = func
# ---> 95 return self._CACHE[self.key_1][self.key_2]
#
# File ~/.local/lib/python3.14/site-packages/galois/_domains/_function.py:68, in Function.key_2(self)
#      65 @property
#      66 def key_2(self):
#      67     if self.field.ufunc_mode == "jit-lookup":
# ---> 68         key = (str(self.__class__), self.field.ufunc_mode, int(self.field.primitive_element))
#      69     else:
#      70         key = (str(self.__class__), self.field.ufunc_mode)
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_meta.py:308, in FieldArrayMeta.primitive_element(cls)
#     274 @property
#     275 def primitive_element(cls) -> FieldArray:
#     276     r"""
#     277     A primitive element of the finite field $\mathrm{GF}(p^m)$.
#     278
#    (...)    306         22
#     307     """
# --> 308     return super().primitive_element
#
# File ~/.local/lib/python3.14/site-packages/galois/_domains/_meta.py:168, in ArrayMeta.primitive_element(cls)
#     163 @property
#     164 def primitive_element(cls) -> Array:
#     165     """
#     166     A primitive element of the Galois field or Galois ring.
#     167     """
# --> 168     return cls(cls._primitive_element)
#
# File ~/.local/lib/python3.14/site-packages/galois/_fields/_array.py:72, in FieldArray.__new__(cls, x, dtype, copy, order, ndmin)
#      66 if cls is FieldArray:
#      67     raise NotImplementedError(
#      68         "FieldArray is an abstract base class that cannot be directly instantiated. "
#      69         "Instead, create a FieldArray subclass for GF(p^m) arithmetic using `GF = galois.GF(p**m)` "
#      70         "and instantiate an array using `x = GF(array_like)`."
#      71     )
# ---> 72 return super().__new__(cls, x, dtype, copy, order, ndmin)
#
# File ~/.local/lib/python3.14/site-packages/galois/_domains/_array.py:56, in Array.__new__(cls, x, dtype, copy, order, ndmin)
#      53 dtype = cls._get_dtype(dtype)
#      55 x = cls._verify_array_like_types_and_values(x)
# ---> 56 array = np.array(x, dtype=dtype, copy=copy, order=order, ndmin=ndmin)
#      58 # Perform view without verification since the elements were verified in _verify_array_like_types_and_values()
#      59 return cls._view(array)
#
# KeyboardInterrupt:
